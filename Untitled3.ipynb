# %% [markdown]
# <a href="https://colab.research.google.com/github/Javier-619/unidad-_3/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *CONCEPTOS BASICOS DE LA LIBRERIA MATPLOTLIB*.
# -----------------
# Matplotlib es una libreria de trasados de grafficos de bajo nivel en python que sive como una herramienta de visualizacion. Matplotlib es un codigo abierto y podemos utilizarlo libremente matplotlib esta escrito principalmente en python con algunos segmentos escritos en C.
# ---------------------------
#   INTALACION DE MATPLOT
#   ----------
#   si tienes python y pip ya instalados en tu sistema instala matplotlib usando el siguiente comando
# "pip install matplotlib"
#
# ------------
# desde la linea de comandos. importar matplotlib
# .
# ---------------
# Una vez instalado matplotlib importalo en tus aplicaciones agregando el modelo import EJEMPLO
#  import matplotlib
#
# matplotlib pyplot
# ------------
# PY PLOT
#  La mayoria de las herramientas de matplotlin se encuentran dentro del submodulo py plot y normalmente se importan bajo el alias ply:
#
#  import matplotlib .pyplot as plt
#
#  ahora el paquete py plot puede denominarce plt
